# %% [markdown]
# ### Import Required Libraries and Set Up Environment Variables

# %%
# Dependencies
import requests
import time
from dotenv import load_dotenv
import os
import pandas as pd
import json

# %%
# Set environment variables from the .env in the local environment
load_dotenv("./project.env")

nyt_api_key = os.getenv("NYT_API_KEY")
tmdb_api_key = os.getenv("TMDB_API_KEY")

# %% [markdown]
# ### Part 1: Access the New York Times API (35 points)

# %%
# Set the base URL
base_url = "https://api.nytimes.com/svc/search/v2/articlesearch.json"

# Filter for movie reviews with "love" in the headline
# section_name should be "Movies"
# type_of_material should be "Review"
# filter_query = 'section_name:"Movies" AND type_of_material:"Review" AND headline:"love"'
filter_query = 'section_name:("Movies") AND type_of_material:("Review") AND headline:("love")'

# Use a sort filter, sort by newest
sort = "newest"

# Select the following fields to return:
# headline, web_url, snippet, source, keywords, pub_date, byline, word_count
field_list = "headline,web_url,snippet,source,keywords,pub_date,byline,word_count"

# Search for reviews published between a begin and end date
begin_date = "20130101"
end_date = "20230531"

# %% [markdown]
# - query_url is correctly constructed (2 points).

# %%
# Build URL
params = {
    "api-key": nyt_api_key,
    "fq": filter_query,
    "sort": sort,
    "fl": field_list,
    "begin_date": begin_date,
    "end_date": end_date
}
request_url = requests.Request('GET', base_url, params=params).prepare().url

# %% [markdown]
# - An empty list reviews_list is created (1 point).

# %%
# Create an empty list to store the reviews
reviews_list = []

# %% [markdown]
# - A for loop is created to loop through 20 times (3 points).
#   - The query_url is extended to include a page (1 point).
#   - A GET request is made to retrieve results and the JSON data is stored in a variable called reviews (4 points).
#   - A 12-second interval is used between queries (2 points).
#   - A try-except clause is used (2 points).
#     - Inside the try clause, there is a loop to loop through the reviews["response"]["docs"] list (3 points).
#     - The reviews results are correctly appended to reviews_list (2 points).
#     - The query page number is printed (1 point).
#     - The except clause prints out the page number that had no results, then breaks from the loop (2 points).

# %%
# loop through pages 0-19
for page in range(20):
    # create query with a page number
    # API results show 10 articles at a time\
    request_by_page_url = f"{request_url}&page={page}"

    # Make a "GET" request and retrieve the JSON
    request = requests.get(request_by_page_url).json()
    
    # Add a twelve second interval between queries to stay within API query limits
    time.sleep(12)
    
    # Try and save the reviews to the reviews_list
    try:
        # loop through the reviews["response"]["docs"] and append each review to the list
        reviews = request.get("response", {}).get("docs", [])
        if not reviews:
            fault = request.get("fault", {}).get("faultstring", "")
            raise Exception(f"No reviews found. {fault}")

        reviews_list.extend(reviews)

        # Print the page that was just retrieved
        print(f"Retrieved page {page}, {len(reviews)} reviews saved")

    # Print the page number that had no results then break from the loop
    except Exception as error:
        print(f"Page {page}: {error}")
        break
# Out:
# Retrieved page 0, 10 reviews saved
# Retrieved page 1, 10 reviews saved
# Retrieved page 2, 10 reviews saved
# Retrieved page 3, 10 reviews saved
# Retrieved page 4, 10 reviews saved
# Retrieved page 5, 10 reviews saved
# Retrieved page 6, 10 reviews saved
# Retrieved page 7, 10 reviews saved
# Retrieved page 8, 10 reviews saved
# Retrieved page 9, 10 reviews saved
# Retrieved page 10, 10 reviews saved
# Retrieved page 11, 10 reviews saved
# Retrieved page 12, 10 reviews saved
# Retrieved page 13, 10 reviews saved
# Retrieved page 14, 10 reviews saved
# Retrieved page 15, 10 reviews saved
# Retrieved page 16, 10 reviews saved
# Retrieved page 17, 10 reviews saved
# Retrieved page 18, 10 reviews saved
# Retrieved page 19, 10 reviews saved

# %% [markdown]
# - json.dumps with the argument indent=4 is used to preview the first five results (2 points).

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data
print(json.dumps(reviews_list[:5], indent=4))
# Out:
# [
#     {
#         "web_url": "https://www.nytimes.com/2023/05/25/movies/the-attachment-diaries-review.html",
#         "snippet": "A gynecologist and her patient form a horrifyingly twisted connection in this batty, bloody Argentine melodrama.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018The Attachment Diaries\u2019 Review: Love, Sick",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "The Attachment Diaries",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "The Attachment Diaries (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Diment, Valentin Javier",
#                 "rank": 3,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-25T11:00:03+0000",
#         "byline": {
#             "original": "By Jeannette Catsoulis",
#             "person": [
#                 {
#                     "firstname": "Jeannette",
#                     "middlename": null,
#                     "lastname": "Catsoulis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 295
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/05/04/movies/whats-love-got-to-do-with-it-review.html",
#         "snippet": "Two childhood friends navigate cultural differences in this pleasantly uncontentious romantic comedy.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Review: \u2018What\u2019s Love Got to Do With It?\u2019 Probably a Lot",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "What\u2019s Love Got to Do With It?",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Kapur, Shekhar",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "James, Lily",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Azmi, Shabana",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Thompson, Emma",
#                 "rank": 5,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-04T17:16:45+0000",
#         "byline": {
#             "original": "By Jeannette Catsoulis",
#             "person": [
#                 {
#                     "firstname": "Jeannette",
#                     "middlename": null,
#                     "lastname": "Catsoulis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 287
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/05/04/movies/you-can-live-forever-review.html",
#         "snippet": "Religion comes between two girls falling in love in the 1990s in this sweet coming-of-age film bathed in grunge hues.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018You Can Live Forever\u2019 Review: Do You Love Me Now?",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "You Can Live Forever",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "You Can Live Forever (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Slutsky, Mark",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Watts, Sarah (Film Director)",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "O'Driscoll, Anwen",
#                 "rank": 5,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Laporte, June (Actor)",
#                 "rank": 6,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-04T11:00:08+0000",
#         "byline": {
#             "original": "By Elisabeth Vincentelli",
#             "person": [
#                 {
#                     "firstname": "Elisabeth",
#                     "middlename": null,
#                     "lastname": "Vincentelli",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 294
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/04/21/movies/a-tourists-guide-to-love-review.html",
#         "snippet": "Rachael Leigh Cook stars in this bland rom-com as a travel executive exploring Vietnam and getting over a breakup.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018A Tourist\u2019s Guide to Love\u2019 Review: A Wearyingly Familiar Trip",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "A Tourist\u2019s  Guide to Love",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "A Tourist's Guide to Love (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Tsuchida, Steven",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Cook, Rachael Leigh",
#                 "rank": 4,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-04-21T07:03:25+0000",
#         "byline": {
#             "original": "By Elisabeth Vincentelli",
#             "person": [
#                 {
#                     "firstname": "Elisabeth",
#                     "middlename": null,
#                     "lastname": "Vincentelli",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 276
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/04/20/movies/other-peoples-children-review.html",
#         "snippet": "A radiant Virginie Efira stars as a Parisian teacher who blissfully falls for a man and his 4-year-old daughter, complicating everyone\u2019s lives.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018Other People\u2019s Children\u2019 Review: True Romance",
#             "kicker": "Critic\u2019s pick",
#             "content_kicker": null,
#             "print_headline": "Intoxicating Love With a Sobering Turn",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Zlotowski, Rebecca",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Other People's Children (Movie)",
#                 "rank": 3,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-04-20T15:35:13+0000",
#         "byline": {
#             "original": "By Manohla Dargis",
#             "person": [
#                 {
#                     "firstname": "Manohla",
#                     "middlename": null,
#                     "lastname": "Dargis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 801
#     }
# ]

# %% [markdown]
# - reviews_list is converted to a Pandas DataFrame using json_normalize() (2 points).

# %%
# Convert reviews_list to a Pandas DataFrame using json_normalize()
reviews_df = pd.json_normalize(reviews_list)
reviews_df.head()
# Out:
#                                              web_url  \
# 0  https://www.nytimes.com/2023/05/25/movies/the-...
# 1  https://www.nytimes.com/2023/05/04/movies/what...
# 2  https://www.nytimes.com/2023/05/04/movies/you-...
# 3  https://www.nytimes.com/2023/04/21/movies/a-to...
# 4  https://www.nytimes.com/2023/04/20/movies/othe...
#
#                                              snippet              source  \
# 0  A gynecologist and her patient form a horrifyi...  The New York Times
# 1  Two childhood friends navigate cultural differ...  The New York Times
# 2  Religion comes between two girls falling in lo...  The New York Times
# 3  Rachael Leigh Cook stars in this bland rom-com...  The New York Times
# 4  A radiant Virginie Efira stars as a Parisian t...  The New York Times
#
#                                             keywords  \
# 0  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 1  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 2  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 3  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 4  [{'name': 'subject', 'value': 'Movies', 'rank'...
#
#                    pub_date  word_count  \
# 0  2023-05-25T11:00:03+0000         295
# 1  2023-05-04T17:16:45+0000         287
# 2  2023-05-04T11:00:08+0000         294
# 3  2023-04-21T07:03:25+0000         276
# 4  2023-04-20T15:35:13+0000         801
#
#                                        headline.main headline.kicker  \
# 0        ‘The Attachment Diaries’ Review: Love, Sick            None
# 1  Review: ‘What’s Love Got to Do With It?’ Proba...            None
# 2  ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 3  ‘A Tourist’s Guide to Love’ Review: A Wearying...            None
# 4     ‘Other People’s Children’ Review: True Romance   Critic’s pick
#
#   headline.content_kicker                 headline.print_headline  \
# 0                    None                  The Attachment Diaries
# 1                    None          What’s Love Got to Do With It?
# 2                    None                    You Can Live Forever
# 3                    None              A Tourist’s  Guide to Love
# 4                    None  Intoxicating Love With a Sobering Turn
#
#   headline.name headline.seo headline.sub           byline.original  \
# 0          None         None         None    By Jeannette Catsoulis
# 1          None         None         None    By Jeannette Catsoulis
# 2          None         None         None  By Elisabeth Vincentelli
# 3          None         None         None  By Elisabeth Vincentelli
# 4          None         None         None         By Manohla Dargis
#
#                                        byline.person byline.organization
# 0  [{'firstname': 'Jeannette', 'middlename': None...                None
# 1  [{'firstname': 'Jeannette', 'middlename': None...                None
# 2  [{'firstname': 'Elisabeth', 'middlename': None...                None
# 3  [{'firstname': 'Elisabeth', 'middlename': None...                None
# 4  [{'firstname': 'Manohla', 'middlename': None, ...                None

# %% [markdown]
# - The title is extracted from the "headline.main" column and is saved in a new column "title" (3 points).

# %%
# Extract the title from the "headline.main" column and
# save it to a new column "title"
# Title is between unicode characters \u2018 and \u2019. 
# End string should include " Review" to avoid cutting title early
reviews_df["title"] = reviews_df["headline.main"].apply(lambda st: st[st.find("\u2018")+1:st.find("\u2019 Review")])

reviews_df
# Out:
#                                                web_url  \
# 0    https://www.nytimes.com/2023/05/25/movies/the-...
# 1    https://www.nytimes.com/2023/05/04/movies/what...
# 2    https://www.nytimes.com/2023/05/04/movies/you-...
# 3    https://www.nytimes.com/2023/04/21/movies/a-to...
# 4    https://www.nytimes.com/2023/04/20/movies/othe...
# ..                                                 ...
# 195  https://www.nytimes.com/2017/03/09/movies/the-...
# 196  https://www.nytimes.com/2017/03/09/movies/revi...
# 197  https://www.nytimes.com/2017/03/02/movies/love...
# 198  https://www.nytimes.com/2017/02/16/movies/ever...
# 199  https://www.nytimes.com/2017/02/09/movies/kedi...
#
#                                                snippet              source  \
# 0    A gynecologist and her patient form a horrifyi...  The New York Times
# 1    Two childhood friends navigate cultural differ...  The New York Times
# 2    Religion comes between two girls falling in lo...  The New York Times
# 3    Rachael Leigh Cook stars in this bland rom-com...  The New York Times
# 4    A radiant Virginie Efira stars as a Parisian t...  The New York Times
# ..                                                 ...                 ...
# 195  This moody romance stars Tatiana Maslany (“Orp...  The New York Times
# 196  A nurse travels to the Ottoman Empire on the e...  The New York Times
# 197  Josh Kornbluth runs afoul of the Internal Reve...  The New York Times
# 198  A messed-up heroine is asked to choose between...  The New York Times
# 199  This documentary profiles distinctive street c...  The New York Times
#
#                                               keywords  \
# 0    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 1    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 2    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 3    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 4    [{'name': 'subject', 'value': 'Movies', 'rank'...
# ..                                                 ...
# 195  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 196  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 197  [{'name': 'creative_works', 'value': 'Love & T...
# 198  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 199  [{'name': 'creative_works', 'value': 'Kedi (Mo...
#
#                      pub_date  word_count  \
# 0    2023-05-25T11:00:03+0000         295
# 1    2023-05-04T17:16:45+0000         287
# 2    2023-05-04T11:00:08+0000         294
# 3    2023-04-21T07:03:25+0000         276
# 4    2023-04-20T15:35:13+0000         801
# ..                        ...         ...
# 195  2017-03-09T21:54:58+0000         251
# 196  2017-03-09T21:53:12+0000         267
# 197  2017-03-02T21:44:18+0000         246
# 198  2017-02-16T21:45:50+0000         256
# 199  2017-02-09T16:21:39+0000         274
#
#                                          headline.main headline.kicker  \
# 0          ‘The Attachment Diaries’ Review: Love, Sick            None
# 1    Review: ‘What’s Love Got to Do With It?’ Proba...            None
# 2    ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 3    ‘A Tourist’s Guide to Love’ Review: A Wearying...            None
# 4       ‘Other People’s Children’ Review: True Romance   Critic’s pick
# ..                                                 ...             ...
# 195  Review: A Combustible Pair Find Love in ‘The O...            None
# 196  Review: Love as the World Wars, in ‘The Ottoma...            None
# 197  Review: It’s All Mirth and Taxes in ‘Love & Ta...            None
# 198  Review: ‘Everybody Loves Somebody,’ a Rom-Com ...            None
# 199  Review: Cute Cats of ‘Kedi,’ Rekindling a ‘Lov...            None
#
#     headline.content_kicker  \
# 0                      None
# 1                      None
# 2                      None
# 3                      None
# 4                      None
# ..                      ...
# 195                    None
# 196                    None
# 197                    None
# 198                    None
# 199                    None
#
#                                headline.print_headline headline.name  \
# 0                               The Attachment Diaries          None
# 1                       What’s Love Got to Do With It?          None
# 2                                 You Can Live Forever          None
# 3                           A Tourist’s  Guide to Love          None
# 4               Intoxicating Love With a Sobering Turn          None
# ..                                                 ...           ...
# 195  Review: A Combustible Pair Find Love in ‘The O...          None
# 196  Review: Love as the World Wars, in ‘The Ottoma...          None
# 197                   It’s Inevitable, Mirth and Taxes          None
# 198                           Everybody Loves Somebody          None
# 199                                               Kedi          None
#
#     headline.seo headline.sub           byline.original  \
# 0           None         None    By Jeannette Catsoulis
# 1           None         None    By Jeannette Catsoulis
# 2           None         None  By Elisabeth Vincentelli
# 3           None         None  By Elisabeth Vincentelli
# 4           None         None         By Manohla Dargis
# ..           ...          ...                       ...
# 195         None         None           By Andy Webster
# 196         None         None        By Neil Genzlinger
# 197         None         None         By Ken Jaworowski
# 198         None         None    By Jeannette Catsoulis
# 199         None         None            By Glenn Kenny
#
#                                          byline.person byline.organization  \
# 0    [{'firstname': 'Jeannette', 'middlename': None...                None
# 1    [{'firstname': 'Jeannette', 'middlename': None...                None
# 2    [{'firstname': 'Elisabeth', 'middlename': None...                None
# 3    [{'firstname': 'Elisabeth', 'middlename': None...                None
# 4    [{'firstname': 'Manohla', 'middlename': None, ...                None
# ..                                                 ...                 ...
# 195  [{'firstname': 'Andy', 'middlename': None, 'la...                None
# 196  [{'firstname': 'Neil', 'middlename': None, 'la...                None
# 197  [{'firstname': 'Ken', 'middlename': None, 'las...                None
# 198  [{'firstname': 'Jeannette', 'middlename': None...                None
# 199  [{'firstname': 'Glenn', 'middlename': None, 'l...                None
#
#                                              title
# 0                           The Attachment Diaries
# 1    What’s Love Got to Do With It?’ Probably a Lo
# 2                             You Can Live Forever
# 3                        A Tourist’s Guide to Love
# 4                          Other People’s Children
# ..                                             ...
# 195                                 The Other Half
# 196                         The Ottoman Lieutenant
# 197                                   Love & Taxes
# 198  Everybody Loves Somebody,’ a Rom-Com With Bit
# 199              Kedi,’ Rekindling a ‘Love of Life
#
# [200 rows x 17 columns]

# %% [markdown]
# - The "keywords" column is correctly converted to string data using the supplied extract_keywords function (3 points).

# %%
# Extract 'name' and 'value' from items in "keywords" column
def extract_keywords(keyword_list):
    extracted_keywords = ""
    for item in keyword_list:
        # Extract 'name' and 'value'
        keyword = f"{item['name']}: {item['value']};" 
        # Append the keyword item to the extracted_keywords list
        extracted_keywords += keyword
    return extracted_keywords

# Fix the "keywords" column by converting cells from a list to a string
reviews_df["keywords"] = reviews_df["keywords"].apply(extract_keywords)

# %% [markdown]
# - A list called titles is created from the "title" column using to_list() (2 points).

# %%
# Create a list from the "title" column using to_list()
# These titles will be used in the query for The Movie Database
titles = reviews_df["title"].to_list()

# %% [markdown]
# ### Access The Movie Database API

# %%
# Prepare The Movie Database query
base_url = "https://api.themoviedb.org/3/search/movie?query="
movie_base_url = "https://api.themoviedb.org/3/movie/"
tmdb_key_string = "&api_key=" + tmdb_api_key

# %% [markdown]
# - An empty list called tmdb_movies_list is created (1 point).
# - A variable called request_counter is created and assigned the value of 1 (1 point).
# - A for loop is created to loop through the titles list (2 points).
#   - request_counter is incremented by 1 (1 point).
#   - time.sleep(1) when request_counter reaches a multiple of 50 (3 points).
#   - A GET request that sends the title to The Movie Database search is performed, and the JSON results are retrieved (4 points).
#   - A try-except clause is used (3 points).
#     - The movie ID is collected from the first result and saved as a variable (2 points).
#     - A GET request is made using the movie query URL and movie ID to retrieve the full movie details in JSON format (4 points).
#     - The genre names are extracted from the results into a list called genres (2 points).
#     - The spoken_languages' English names are extracted from the results into a list called spoken_languages (2 points).
#     - The production_countries' names are extracted from the results into a list called production_countries (2 points).
#     - A dictionary is created with the specified 15 fields (4 points).
#     - The results dictionary is appended to the tmdb_movies_list list (3 points).
#     - A message is printed with the name of the movie to indicate that the title was found. (1 point)
#   - The except clause prints out a statement if a movie is not found (1 point).

# %%
# Create an empty list to store the results
tmdb_movies_list = []

# Create a request counter to sleep the requests after a multiple of 50 requests
request_counter = 0

# Loop through the titles
for title in titles:
    # Check if we need to sleep before making a request
    if request_counter % 50 == 0 and request_counter != 0: time.sleep(1)

    # Add 1 to the request counter
    request_counter += 1
    
    # Perform a "GET" request for The Movie Database
    request = requests.get(base_url + title + tmdb_key_string).json()

    # Include a try clause to search for the full movie details.
    # Use the except clause to print out a statement if a movie is not found.
    try:
        # Get movie id
        movie_id = request["results"][0]["id"]

        # Make a request for a the full movie details
        movie_url = f"{movie_base_url}{movie_id}?{tmdb_key_string}"

        # Execute "GET" request with url
        movie_request = requests.get(movie_url).json()
        
        # Extract the genre names into a list
        movie_genres = [genre["name"] for genre in movie_request["genres"]]

        # Extract the spoken_languages' English name into a list
        movie_languages = [lang["english_name"] for lang in movie_request["spoken_languages"]]

        # Extract the production_countries' name into a list
        movie_countries = [country["name"] for country in movie_request["production_countries"]]

        # Add the relevant data to a dictionary and
        # append it to the tmdb_movies_list list
        tmdb_movies_list.append({
            "title": movie_request["title"],
            "original_title": movie_request["original_title"],
            "budget": movie_request["budget"],
            "original_language": movie_request["original_language"],
            "homepage": movie_request["homepage"],
            "overview": movie_request["overview"],
            "popularity": movie_request["popularity"],
            "runtime": movie_request["runtime"],
            "revenue": movie_request["revenue"],
            "release_date": movie_request["release_date"],
            "vote_average": movie_request["vote_average"],
            "vote_count": movie_request["vote_count"],
            "genres": movie_genres,
            "spoken_languages": movie_languages,
            "production_countries": movie_countries
        })

        # Print out the title that was found
        print(f"Found: {title}")
    except:
        print(f"NOT Found: {title}")
# Out:
# Found: The Attachment Diaries
# NOT Found: What’s Love Got to Do With It?’ Probably a Lo
# Found: You Can Live Forever
# Found: A Tourist’s Guide to Love
# Found: Other People’s Children
# Found: One True Loves
# Found: The Lost Weekend: A Love Story
# Found: A Thousand and One
# Found: Your Place or Mine
# Found: Love in the Time of Fentanyl
# Found: Pamela, a Love Story
# Found: In From the Side
# Found: After Love
# Found: Alcarràs
# Found: Nelly & Nadine
# Found: Lady Chatterley’s Lover
# Found: The Sound of Christmas
# Found: The Inspection
# Found: Bones and All
# Found: My Policeman
# Found: About Fate
# Found: Waiting for Bojangles
# Found: I Love My Dad
# Found: A Love Song
# Found: Alone Together
# Found: Art of Love
# Found: The Wheel
# Found: Thor: Love and Thunder
# Found: Both Sides of the Blade
# Found: Fire of Love
# Found: Love & Gelato
# Found: Stay Prayed Up
# Found: Benediction
# Found: Dinner in America
# Found: In a New York Minute
# Found: Anaïs in Love
# Found: I Love America
# Found: See You Then
# Found: La Mami
# Found: Love After Love
# Found: Deep Water
# Found: Lucy and Desi
# Found: Cyrano
# Found: The In Between
# Found: Book of Love
# Found: Lingui, the Sacred Bonds
# Found: The Pink Cloud
# Found: A Journal for Jordan
# Found: West Side Story
# NOT Found: Aulcie
# Found: Love Is Love Is Love
# Found: Love Hard
# Found: Bergman Island
# Found: Hard Luck Love Song
# Found: South of Heaven
# Found: Wife of a Spy
# Found: Happier Than Ever
# Found: Together
# Found: Annette
# Found: Resort to Love
# Found: Woodstock 99: Peace, Love and Rage
# Found: Casanova, Last Love
# Found: Running Against the Wind
# Found: Asia
# Found: Undine
# Found: This Town
# Found: Tu Me Manques
# Found: Monday
# Found: Ride or Die
# Found: Future People
# Found: Luz
# Found: Happily
# Found: This Is the Life
# Found: To All the Boys: Always and Forever
# Found: Young Hearts
# Found: Little Fish
# Found: Two of Us
# Found: Atlantis
# Found: Preparations to Be Together
# Found: Your Name Engraved Herein
# Found: Sylvie’s Love
# Found: Ariana Grande: Excuse Me, I Love You
# Found: Museum Town
# Found: Wild Mountain Thyme
# Found: My Psychedelic Love Story
# Found: 69: The Saga of Danny Hernandez
# Found: Ammonite
# Found: Love and Monsters
# Found: Dick Johnson Is Dead
# Found: Love, Guaranteed
# Found: Feel the Beat
# Found: Babyteeth
# Found: Spelling the Dream
# Found: A Secret Love
# Found: Love Wedding Repeat
# Found: Almost Love
# Found: Hope Gap
# Found: All the Bright Places
# Found: The Photograph
# Found: You Go to My Head
# Found: Ordinary Love
# Found: To All the Boys: P.S. I Still Love You
# Found: The Woman Who Loves Giraffes
# Found: Queen & Slim
# Found: Marriage Story
# Found: Cyrano, My Love
# Found: Pretenders
# Found: First Love
# Found: Loro
# Found: Falling Inn Love
# Found: Hot Air
# Found: Love, Antosha
# Found: Leto
# Found: The Tomorrow Man
# Found: Asako I & II
# Found: The Sun Is Also a Star
# Found: Shéhérazade
# Found: Long Shot
# Found: Clara
# Found: Kalank
# Found: Rafiki
# Found: Diane
# Found: Five Feet Apart
# Found: Ash Is Purest White
# Found: Gloria Bell
# Found: Black Mother
# Found: The Hole in the Ground
# Found: How to Train Your Dragon: The Hidden World
# Found: A Tuba to Cuba
# Found: Fighting With My Family
# Found: Sorry Angel
# Found: Berlin, I Love You
# Found: Untogether
# Found: Cold War
# Found: If Beale Street Could Talk
# Found: Asher
# Found: The Party’s Just Beginning
# Found: The Great Pretender
# Found: Sicilian Ghost Story
# Found: The New Romantic
# Found: Pimp
# Found: In a Relationship
# NOT Found: They’ll Love Me When I’m Dead’ Documents Orson Welles’s Last Fil
# NOT Found: Burning,’ Love Ignites a Divided Worl
# NOT Found: After Everything,’ a Young Love Blooms in Crisi
# NOT Found: Quincy’ Captures a Lifelong Love Affair With Musi
# NOT Found: Love, Gilda,’ a Portrait of a Brief and Brilliant Caree
# NOT Found: Tea With the Dames,’ Four Legends Dish on Acting and Lov
# NOT Found: Bel Canto,’ Music Is the Food of Love and Rebellio
# NOT Found: The Citizen,’ an Immigrant Picks a Bad Time to Fall in Lov
# NOT Found: Love, Cecil,’ an Aesthete Ahead of His Tim
# Found: How to Talk to Girls at Parties
# NOT Found: Rogers Park,’ Life and Love in a Chicago Neighborhoo
# Found: Love & Bananas,’ Uncovering the Plight of the Asian Elephan
# Found: Godard Mon Amour
# NOT Found: Submergence,’ a Love Story Sunk by Geopolitic
# NOT Found: Love After Love,’ an Unflinching Look at Extended Grie
# Found: Outside In
# NOT Found: Love, Simon,’ a Glossy Teen Romance, the Hero Has a Secre
# NOT Found: Keep the Change,’ Two People With Autism Find Lov
# Found: The Party
# NOT Found: The Housemaid,’ Twisted Love and Angry Ghosts in Vietna
# NOT Found: Forever My Girl,’ a Romance Resumes After a Long Brea
# NOT Found: Kangaroo: A Love-Hate Story’ Exposes a Wildlife Massacr
# Found: Lover for a Day
# NOT Found: Youth,’ the People’s Dance Troupe, in Love and Wa
# NOT Found: Killing for Love’ Revisits a Virginia Murder Cas
# NOT Found: The Shape of Water’ Is Altogether Wonderfu
# NOT Found: Love Beats Rhymes,’ a Hip-Hop Artist Transformed by Poetr
# NOT Found: Cuba and the Cameraman’ Lavishes Love on a Country … and Castr
# NOT Found: On the Beach at Night Alone’ Zooms in on a Love Affai
# NOT Found: Thelma,’ a Woman in Love Can Burn Down the Worl
# NOT Found: Hello Again,’ a Movie Musical Ode to Love and Lust Over Decade
# NOT Found: It Happened in L.A.,’ All That Questing After Lov
# Found: God’s Own Country
# Found: The Mountain Between Us
# NOT Found: Dina,’ a Differently Abled Love Stor
# Found: In Search of Fellini
# NOT Found: Woodpeckers,’ a Tale of Love and Agonizing Penal Confinemen
# NOT Found: I Do ... Until I Don’t,’ Love and Loathing in Florid
# NOT Found: Tales of an Immoral Couple’: Love Means Having to Grow U
# NOT Found: After Love’ and Regretting Every Momen
# Found: The Last Face
# NOT Found: Women Who Kill,’ and May Be in Love With On
# NOT Found: False Confessions,’ the Play’s Not Quite the Thin
# NOT Found: Review: Those Movies, Himself — Bertrand Tavernier’s Tour of French Cinem
# NOT Found: The Big Sick,’ Comedy Is Hard, Love Harde
# Found: Lost in Paris
# NOT Found: Vincent N Roxxy,’ Love Is in the Air, N So Is Fea
# NOT Found: Everything, Everything’ Pits Love Against Diseas
# NOT Found: Hounds of Love’ Is Tense and Deadly Down Unde
# NOT Found: Harold and Lillian’ Introduces a Hollywood Power Coupl
# NOT Found: The Happiest Day in the Life of Olli Maki,’ Love and Life on the Rope
# NOT Found: The Promise’ Finds a Love Triangle in Constantinopl
# NOT Found: Frantz,’ a Mysterious Frenchman and the Wounds of Wa
# Found: The Other Half
# Found: The Ottoman Lieutenant
# Found: Love & Taxes
# NOT Found: Everybody Loves Somebody,’ a Rom-Com With Bit
# NOT Found: Kedi,’ Rekindling a ‘Love of Life

# %% [markdown]
# - The first five results are previewed using json.dumps with the argument indent=4 (2 points).

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data
print(json.dumps(tmdb_movies_list[:5], indent=4))
# Out:
# [
#     {
#         "title": "The Attachment Diaries",
#         "original_title": "El apego",
#         "budget": 0,
#         "original_language": "es",
#         "homepage": "",
#         "overview": "Argentina, 1970s. A desperate young woman goes to a clinic to have a clandestine abortion. As her pregnancy is already through the fourth month, the doctor refuses. Instead, she proposes to sell the baby to one of her clients and offers to provide shelter in her house until the child is born. Their disturbed personalities will become intertwined in a strange and dangerous relationship.",
#         "popularity": 0.765,
#         "runtime": 102,
#         "revenue": 0,
#         "release_date": "2021-10-07",
#         "vote_average": 3.0,
#         "vote_count": 4,
#         "genres": [
#             "Drama",
#             "Mystery",
#             "Thriller",
#             "Horror"
#         ],
#         "spoken_languages": [
#             "Spanish"
#         ],
#         "production_countries": [
#             "Argentina"
#         ]
#     },
#     {
#         "title": "You Can Live Forever",
#         "original_title": "You Can Live Forever",
#         "budget": 0,
#         "original_language": "en",
#         "homepage": "https://gooddeedentertainment.com/you-can-live-forever/",
#         "overview": "When Jaime, a gay teenager, is sent to live in a community of Jehovah's Witnesses in small-town Quebec, she falls madly in love with a devout Witness girl. The two embark on an intense affair with consequences that will reshape the rest of their lives.",
#         "popularity": 23.028,
#         "runtime": 96,
#         "revenue": 15055,
#         "release_date": "2023-03-24",
#         "vote_average": 6.6,
#         "vote_count": 40,
#         "genres": [
#             "Drama",
#             "Romance"
#         ],
#         "spoken_languages": [
#             "English",
#             "French"
#         ],
#         "production_countries": [
#             "Canada",
#             "United States of America"
#         ]
#     },
#     {
#         "title": "A Tourist's Guide to Love",
#         "original_title": "A Tourist's Guide to Love",
#         "budget": 0,
#         "original_language": "en",
#         "homepage": "https://www.netflix.com/title/81424906",
#         "overview": "After an unexpected break up, a travel executive accepts an assignment to go undercover and learn about the tourist industry in Vietnam. Along the way, she finds adventure and romance with her Vietnamese expat tour guide and they decide to hijack the tour bus in order to explore life and love off the beaten path.",
#         "popularity": 17.027,
#         "runtime": 96,
#         "revenue": 0,
#         "release_date": "2023-04-21",
#         "vote_average": 6.303,
#         "vote_count": 170,
#         "genres": [
#             "Romance",
#             "Comedy"
#         ],
#         "spoken_languages": [
#             "English",
#             "Vietnamese"
#         ],
#         "production_countries": [
#             "United States of America"
#         ]
#     },
#     {
#         "title": "Other People's Children",
#         "original_title": "Les Enfants des autres",
#         "budget": 0,
#         "original_language": "fr",
#         "homepage": "https://www.wildbunch.biz/movie/other-peoples-children/",
#         "overview": "Rachel loves her life, her students, her friends, her ex, her guitar lessons. When she falls in love with Ali, she grows close to his 4-year-old daughter, Leila. She tucks her in, looks after her, and loves her like a mother... which she isn\u2019t. Not yet. Rachel is 40. The desire for a family of her own is growing stronger, and the clock is ticking. Is it too late?",
#         "popularity": 7.627,
#         "runtime": 104,
#         "revenue": 84178,
#         "release_date": "2022-09-21",
#         "vote_average": 6.812,
#         "vote_count": 194,
#         "genres": [
#             "Drama",
#             "Comedy"
#         ],
#         "spoken_languages": [
#             "French",
#             "English"
#         ],
#         "production_countries": [
#             "France"
#         ]
#     },
#     {
#         "title": "One True Loves",
#         "original_title": "One True Loves",
#         "budget": 0,
#         "original_language": "en",
#         "homepage": "",
#         "overview": "Emma and Jesse are living the perfect life together, until Jesse disappears in a tragic helicopter crash on their first wedding anniversary. Four years later, Emma has found happiness again and is about to marry her best friend when Jesse resurfaces, turning her world upside down and leaving her torn between two great loves.",
#         "popularity": 12.419,
#         "runtime": 100,
#         "revenue": 37820,
#         "release_date": "2023-04-07",
#         "vote_average": 6.451,
#         "vote_count": 81,
#         "genres": [
#             "Romance",
#             "Comedy",
#             "Drama"
#         ],
#         "spoken_languages": [
#             "English",
#             "Spanish"
#         ],
#         "production_countries": [
#             "Czech Republic",
#             "United States of America"
#         ]
#     }
# ]

# %% [markdown]
# - The results are converted to a DataFrame called tmdb_df with pd.DataFrame() (2 points).

# %%
# Convert the results to a DataFrame
tmdb_movies_df = pd.DataFrame(tmdb_movies_list)
tmdb_movies_df
# Out:
#                          title               original_title    budget  \
# 0       The Attachment Diaries                     El apego         0
# 1         You Can Live Forever         You Can Live Forever         0
# 2    A Tourist's Guide to Love    A Tourist's Guide to Love         0
# 3      Other People's Children       Les Enfants des autres         0
# 4               One True Loves               One True Loves         0
# ..                         ...                          ...       ...
# 149              The Last Face                The Last Face         0
# 150              Lost in Paris              Paris pieds nus         0
# 151             The Other Half               The Other Half         0
# 152     The Ottoman Lieutenant       The Ottoman Lieutenant  40000000
# 153           Mektoub, My Love  Mektoub, My Love: Canto Uno         0
#
#     original_language                                           homepage  \
# 0                  es
# 1                  en  https://gooddeedentertainment.com/you-can-live...
# 2                  en             https://www.netflix.com/title/81424906
# 3                  fr  https://www.wildbunch.biz/movie/other-peoples-...
# 4                  en
# ..                ...                                                ...
# 149                en
# 150                fr
# 151                en                      http://theotherhalfmovie.com/
# 152                en  https://www.uphe.com/movies/the-ottoman-lieute...
# 153                fr  https://www.pathefilms.com/film/mektoubmylovec...
#
#                                               overview  popularity  runtime  \
# 0    Argentina, 1970s. A desperate young woman goes...       0.765      102
# 1    When Jaime, a gay teenager, is sent to live in...      23.028       96
# 2    After an unexpected break up, a travel executi...      17.027       96
# 3    Rachel loves her life, her students, her frien...       7.627      104
# 4    Emma and Jesse are living the perfect life tog...      12.419      100
# ..                                                 ...         ...      ...
# 149  Miguel, a heroic Spanish doctor, puts himself ...      12.209      130
# 150  Fiona visits Paris for the first time to assis...       7.768       83
# 151  A grief-stricken man and a bipolar woman fall ...       2.912      103
# 152  Lillie, a determined American woman, ventures ...      11.641      111
# 153  Amin, an aspiring screenwriter living in Paris...      20.744      181
#
#      revenue release_date  vote_average  vote_count  \
# 0          0   2021-10-07         3.000           4
# 1      15055   2023-03-24         6.600          40
# 2          0   2023-04-21         6.303         170
# 3      84178   2022-09-21         6.812         194
# 4      37820   2023-04-07         6.451          81
# ..       ...          ...           ...         ...
# 149        0   2017-01-11         5.500         194
# 150        0   2017-01-14         6.000         115
# 151        0   2016-12-02         6.300          24
# 152   413844   2017-03-28         6.163         248
# 153  1200387   2017-09-07         6.709         297
#
#                                  genres           spoken_languages  \
# 0    [Drama, Mystery, Thriller, Horror]                  [Spanish]
# 1                      [Drama, Romance]          [English, French]
# 2                     [Romance, Comedy]      [English, Vietnamese]
# 3                       [Drama, Comedy]          [French, English]
# 4              [Romance, Comedy, Drama]         [English, Spanish]
# ..                                  ...                        ...
# 149                             [Drama]      [English, Portuguese]
# 150                            [Comedy]                   [French]
# 151                    [Drama, Romance]                  [English]
# 152               [Romance, Drama, War]         [Turkish, English]
# 153                    [Romance, Drama]  [Arabic, English, French]
#
#                            production_countries
# 0                                   [Argentina]
# 1            [Canada, United States of America]
# 2                    [United States of America]
# 3                                      [France]
# 4    [Czech Republic, United States of America]
# ..                                          ...
# 149                  [United States of America]
# 150                           [Belgium, France]
# 151                                    [Canada]
# 152          [Turkey, United States of America]
# 153                             [France, Italy]
#
# [154 rows x 15 columns]

# %% [markdown]
# ### Merge and Clean the Data for Export

# %% [markdown]
# - The New York Times reviews and TMDB DataFrames are merged on the title column (4 points).

# %%
# Merge the New York Times reviews and TMDB DataFrames on title
merged_df = pd.merge(tmdb_movies_df, reviews_df, on="title", how="left")
merged_df
# Out:
#                          title               original_title    budget  \
# 0       The Attachment Diaries                     El apego         0
# 1         You Can Live Forever         You Can Live Forever         0
# 2    A Tourist's Guide to Love    A Tourist's Guide to Love         0
# 3      Other People's Children       Les Enfants des autres         0
# 4               One True Loves               One True Loves         0
# ..                         ...                          ...       ...
# 149              The Last Face                The Last Face         0
# 150              Lost in Paris              Paris pieds nus         0
# 151             The Other Half               The Other Half         0
# 152     The Ottoman Lieutenant       The Ottoman Lieutenant  40000000
# 153           Mektoub, My Love  Mektoub, My Love: Canto Uno         0
#
#     original_language                                           homepage  \
# 0                  es
# 1                  en  https://gooddeedentertainment.com/you-can-live...
# 2                  en             https://www.netflix.com/title/81424906
# 3                  fr  https://www.wildbunch.biz/movie/other-peoples-...
# 4                  en
# ..                ...                                                ...
# 149                en
# 150                fr
# 151                en                      http://theotherhalfmovie.com/
# 152                en  https://www.uphe.com/movies/the-ottoman-lieute...
# 153                fr  https://www.pathefilms.com/film/mektoubmylovec...
#
#                                               overview  popularity  runtime  \
# 0    Argentina, 1970s. A desperate young woman goes...       0.765      102
# 1    When Jaime, a gay teenager, is sent to live in...      23.028       96
# 2    After an unexpected break up, a travel executi...      17.027       96
# 3    Rachel loves her life, her students, her frien...       7.627      104
# 4    Emma and Jesse are living the perfect life tog...      12.419      100
# ..                                                 ...         ...      ...
# 149  Miguel, a heroic Spanish doctor, puts himself ...      12.209      130
# 150  Fiona visits Paris for the first time to assis...       7.768       83
# 151  A grief-stricken man and a bipolar woman fall ...       2.912      103
# 152  Lillie, a determined American woman, ventures ...      11.641      111
# 153  Amin, an aspiring screenwriter living in Paris...      20.744      181
#
#      revenue release_date  ...  \
# 0          0   2021-10-07  ...
# 1      15055   2023-03-24  ...
# 2          0   2023-04-21  ...
# 3      84178   2022-09-21  ...
# 4      37820   2023-04-07  ...
# ..       ...          ...  ...
# 149        0   2017-01-11  ...
# 150        0   2017-01-14  ...
# 151        0   2016-12-02  ...
# 152   413844   2017-03-28  ...
# 153  1200387   2017-09-07  ...
#
#                                          headline.main  headline.kicker  \
# 0          ‘The Attachment Diaries’ Review: Love, Sick             None
# 1    ‘You Can Live Forever’ Review: Do You Love Me ...             None
# 2                                                  NaN              NaN
# 3                                                  NaN              NaN
# 4       ‘One True Loves’ Review: A Romance Lost at Sea             None
# ..                                                 ...              ...
# 149  Review: Aid Workers in Love and War in Sean Pe...             None
# 150  Review: Finding Love (and Slapstick) While ‘Lo...             None
# 151  Review: A Combustible Pair Find Love in ‘The O...             None
# 152  Review: Love as the World Wars, in ‘The Ottoma...             None
# 153                                                NaN              NaN
#
#     headline.content_kicker  \
# 0                      None
# 1                      None
# 2                       NaN
# 3                       NaN
# 4                      None
# ..                      ...
# 149                    None
# 150                    None
# 151                    None
# 152                    None
# 153                     NaN
#
#                                headline.print_headline headline.name  \
# 0                               The Attachment Diaries          None
# 1                                 You Can Live Forever          None
# 2                                                  NaN           NaN
# 3                                                  NaN           NaN
# 4                                       One True Loves          None
# ..                                                 ...           ...
# 149                                      The Last Face          None
# 150                                      Lost in Paris          None
# 151  Review: A Combustible Pair Find Love in ‘The O...          None
# 152  Review: Love as the World Wars, in ‘The Ottoma...          None
# 153                                                NaN           NaN
#
#     headline.seo headline.sub           byline.original  \
# 0           None         None    By Jeannette Catsoulis
# 1           None         None  By Elisabeth Vincentelli
# 2            NaN          NaN                       NaN
# 3            NaN          NaN                       NaN
# 4           None         None             By Brandon Yu
# ..           ...          ...                       ...
# 149         None         None            By Glenn Kenny
# 150         None         None         By Ben Kenigsberg
# 151         None         None           By Andy Webster
# 152         None         None        By Neil Genzlinger
# 153          NaN          NaN                       NaN
#
#                                          byline.person byline.organization
# 0    [{'firstname': 'Jeannette', 'middlename': None...                None
# 1    [{'firstname': 'Elisabeth', 'middlename': None...                None
# 2                                                  NaN                 NaN
# 3                                                  NaN                 NaN
# 4    [{'firstname': 'Brandon', 'middlename': None, ...                None
# ..                                                 ...                 ...
# 149  [{'firstname': 'Glenn', 'middlename': None, 'l...                None
# 150  [{'firstname': 'Ben', 'middlename': None, 'las...                None
# 151  [{'firstname': 'Andy', 'middlename': None, 'la...                None
# 152  [{'firstname': 'Neil', 'middlename': None, 'la...                None
# 153                                                NaN                 NaN
#
# [154 rows x 31 columns]

# %% [markdown]
# - A list called columns_to_fix is created to store the names of the genres, spoken_languages, and production_countries columns (2 points).
# - A list is created called characters_to_remove containing [, ], and ' (2 points).
# - A for loop is created to loop through columns_to_fix (2 points).
#   - The columns to fix are converted to the string data type (2 points).
#   - characters_to_remove is looped through to remove the characters from the string using the Pandas str.replace() method (4 points).
# - The head of the updated DataFrame is displayed to confirm the list characters were removed (2 points).

# %%
# Remove list brackets and quotation marks on the columns containing lists
# Create a list of the columns that need fixing
columns_to_fix = ["genres", "spoken_languages", "production_countries"]

# Create a list of characters to remove
chars_to_remove = ["[", "]", "'"]

# Loop through the list of columns to fix
for column in columns_to_fix:

    # Convert the column to type 'str'
    merged_df[column] = merged_df[column].astype(str)

    # Loop through characters to remove
    for char in chars_to_remove:
        merged_df[column] = merged_df[column].str.replace(char, "")

# Display the fixed DataFrame
merged_df.head()
# Out:
#                        title             original_title  budget  \
# 0     The Attachment Diaries                   El apego       0
# 1       You Can Live Forever       You Can Live Forever       0
# 2  A Tourist's Guide to Love  A Tourist's Guide to Love       0
# 3    Other People's Children     Les Enfants des autres       0
# 4             One True Loves             One True Loves       0
#
#   original_language                                           homepage  \
# 0                es
# 1                en  https://gooddeedentertainment.com/you-can-live...
# 2                en             https://www.netflix.com/title/81424906
# 3                fr  https://www.wildbunch.biz/movie/other-peoples-...
# 4                en
#
#                                             overview  popularity  runtime  \
# 0  Argentina, 1970s. A desperate young woman goes...       0.765      102
# 1  When Jaime, a gay teenager, is sent to live in...      23.028       96
# 2  After an unexpected break up, a travel executi...      17.027       96
# 3  Rachel loves her life, her students, her frien...       7.627      104
# 4  Emma and Jesse are living the perfect life tog...      12.419      100
#
#    revenue release_date  ...  \
# 0        0   2021-10-07  ...
# 1    15055   2023-03-24  ...
# 2        0   2023-04-21  ...
# 3    84178   2022-09-21  ...
# 4    37820   2023-04-07  ...
#
#                                        headline.main  headline.kicker  \
# 0        ‘The Attachment Diaries’ Review: Love, Sick             None
# 1  ‘You Can Live Forever’ Review: Do You Love Me ...             None
# 2                                                NaN              NaN
# 3                                                NaN              NaN
# 4     ‘One True Loves’ Review: A Romance Lost at Sea             None
#
#   headline.content_kicker headline.print_headline headline.name headline.seo  \
# 0                    None  The Attachment Diaries          None         None
# 1                    None    You Can Live Forever          None         None
# 2                     NaN                     NaN           NaN          NaN
# 3                     NaN                     NaN           NaN          NaN
# 4                    None          One True Loves          None         None
#
#   headline.sub           byline.original  \
# 0         None    By Jeannette Catsoulis
# 1         None  By Elisabeth Vincentelli
# 2          NaN                       NaN
# 3          NaN                       NaN
# 4         None             By Brandon Yu
#
#                                        byline.person byline.organization
# 0  [{'firstname': 'Jeannette', 'middlename': None...                None
# 1  [{'firstname': 'Elisabeth', 'middlename': None...                None
# 2                                                NaN                 NaN
# 3                                                NaN                 NaN
# 4  [{'firstname': 'Brandon', 'middlename': None, ...                None
#
# [5 rows x 31 columns]

# %% [markdown]
# - The byline.person column is dropped (2 points).

# %%
# Drop "byline.person" column
merged_df.drop(columns="byline.person", inplace=True)

# %% [markdown]
# - Duplicate rows are deleted (1 point).
# - The DataFrame index is reset (1 point).

# %%
# Delete duplicate rows and reset index
merged_df.drop_duplicates(inplace=True)
merged_df.reset_index(drop=True, inplace=True)

# %% [markdown]
# - The DataFrame is exported to a CSV file without the index (3 points).

# %%
# Export data to CSV without the index
merged_df.to_csv("output/retrieved_movie_data.csv", index=False)
